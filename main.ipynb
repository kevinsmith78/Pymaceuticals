# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import sem
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
#Evalute Which Colums are in this dataset
mouse_metadata.head(100)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0      k403     Ramicane    Male          21          16
# 1      s185    Capomulin  Female           3          17
# 2      x401    Capomulin  Female          16          15
# 3      m601    Capomulin    Male          22          17
# 4      g791     Ramicane    Male          11          16
# ..      ...          ...     ...         ...         ...
# 95     f345    Infubinol    Male          23          26
# 96     f394    Zoniferol    Male          19          30
# 97     f436     Ceftamin  Female           3          25
# 98     f545    Zoniferol  Female          20          26
# 99     f932     Ketapril    Male          15          29
#
# [100 rows x 5 columns]

# %%
study_results.head(2)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0

# %%
# Combine the data into a single dataset
pharma_complete = pd.merge(mouse_metadata, study_results,on="Mouse ID", how="left")

# %%
# Display the data table for preview
pharma_complete
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
#Explore Data Types
pharma_complete.dtypes
# Out:
# Mouse ID               object
# Drug Regimen           object
# Sex                    object
# Age_months              int64
# Weight (g)              int64
# Timepoint               int64
# Tumor Volume (mm3)    float64
# Metastatic Sites        int64
# dtype: object

# %%
# Checking the number of mice.
pharma_complete['Mouse ID'].count()
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
pharma_complete_df = pharma_complete[pharma_complete.duplicated(['Mouse ID', 'Timepoint'])]
pharma_complete_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID.
pharma_complete_data = pharma_complete[pharma_complete.duplicated(['Mouse ID',])]
pharma_complete_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# 5              33.464577                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1644 rows x 8 columns]

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
#clean_pharma = pharma_complete.drop_duplicates("Mouse ID = g989")
clean_pharma = pharma_complete[pharma_complete["Mouse ID"]!= "g989"]
clean_pharma
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
clean_pharma['Mouse ID'].nunique()
len(clean_pharma['Mouse ID'].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
summary_tumor_df= clean_pharma.groupby('Drug Regimen')

# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# %%
pharma_mean = summary_tumor_df['Tumor Volume (mm3)'].mean()
pharma_mean
print(type(pharma_mean))
print(pharma_mean)
# Out:
# <class 'pandas.core.series.Series'>
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.320930
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
pharma_median = summary_tumor_df ['Tumor Volume (mm3)'].median()
pharma_median
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.446266
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
pharma_variance= summary_tumor_df['Tumor Volume (mm3)'].var()
pharma_variance
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     43.852013
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
pharma_st_d= summary_tumor_df['Tumor Volume (mm3)'].std()
pharma_st_d
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.622085
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
pharma_sem= summary_tumor_df.sem()['Tumor Volume (mm3)']
pharma_sem
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.544332
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %%
#summary_pharma_df = pd.DataFrame({'Mean':pharma_sem})
summary_pharma_df = pd.DataFrame({'Mean':pharma_mean,'Median':pharma_median,'Variance':pharma_variance,'Standard Deviation':pharma_st_d,'SEM':pharma_sem})
summary_pharma_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
summary_pharma_df = pd.DataFrame({'Mean':pharma_mean,'Median':pharma_median,'Variance':pharma_variance,'Standard Deviation':pharma_st_d,'SEM':pharma_sem})
summary_pharma_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Using the aggregation method, produce the same summary statistics in a single line

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
pharma_bar = clean_pharma.groupby(["Drug Regimen"]).count()["Mouse ID"]
bar_chart= pharma_bar.plot.bar(figsize=(10,5),color ='c',fontsize = 10)
# add gridlines
plt.grid(alpha=0.3)
# add Labels
plt.xlabel("Drug Regimen",fontsize=15)
plt.ylabel("Number of Mice", fontsize=15)
plt.title("Number of Mice vs type of Drug", fontsize = 20)
#plt.show()
#bar_chart
# Out:
# Text(0.5, 1.0, 'Number of Mice vs type of Drug')

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot
mice_list_count = clean_pharma['Drug Regimen'].value_counts()

# %%
x_axis=np.arange(len(mice_list_count))
tick_location = [value for value in x_axis]

# %%
plt.figure(figsize=(10,3))
plt.bar(x_axis, mice_list_count,color='r', alpha=0.9, align="center")
plt.xticks(tick_location,mice_list_count.index.values)
plt.xticks(rotation='vertical')
plt.xlim(-0.75),len(x_axis)-0.25
plt.ylim(0,max(mice_list_count)+5)
plt.title("Number of Mice per Regiment", fontsize = 20)
plt.xlabel("Drug Regimen", fontsize = 20)
plt.ylabel("Number of Mice",fontsize = 20)
plt.grid (alpha=.3)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
pharma_pie = clean_pharma.groupby(["Sex"]).count()["Mouse ID"]
pharma_pie.plot.pie(y=(''),figsize=(7,7),autopct="%1.1f%%",shadow=True, startangle=70)
plt.title("Distribution Of Gender within Study", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Distribution Of Gender within Study')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
py_data = (clean_pharma.groupby (["Sex"])["Mouse ID"].count()).tolist()
py_data
# Out:
# [922, 958]

# %%
#establish, labels , colours
labels = ["Females","Males"]
colors = ["red" , "Blue"]

# %%
plt.pie(py_data,labels=labels,colors=colors, autopct = "%1.1f%%", startangle=90)
plt.axis("equal")
# Out:
# (-1.1079114197007642,
#  1.1041200173094385,
#  -1.1065502689644005,
#  1.1003119175697333)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Out:
# Mouse ID
# a203    45
# a251    45
# a262    45
# a275    45
# a366    30
#         ..
# z435    10
# z578    45
# z581    45
# z795    45
# z969    45
# Name: Timepoint, Length: 248, dtype: int64

# %%
# Start by getting the last (greatest) timepoint for each mouse
final_tumor_df = clean_pharma.groupby(["Mouse ID"])["Timepoint"].max()
print(final_tumor_df)
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 309      b128    Capomulin  Female           9          22         45
# 299      b742    Capomulin    Male           7          21         45
# 244      g288    Capomulin    Male           3          19         45
# 360      g316    Capomulin  Female          22          22         45
# 440      i557    Capomulin  Female           1          24         45
# ...       ...          ...     ...         ...         ...        ...
# 1344     p136    Zoniferol  Female           5          28         45
# 1416     q511    Zoniferol  Female           2          28         45
# 1434     q633    Zoniferol    Male          12          25         45
# 1518     s337    Zoniferol    Male          14          27         45
# 1719     w575    Zoniferol  Female          16          28         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 309            38.982878                 2
# 299            38.939633                 0
# 244            37.074024                 1
# 360            40.159220                 2
# 440            47.685963                 1
# ...                  ...               ...
# 1344           63.488697                 2
# 1416           68.611061                 3
# 1434           70.827796                 2
# 1518           62.109651                 4
# 1719           68.401286                 3
#
# [130 rows x 8 columns]

# %%
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
pharma_merge = pd.merge(pharma_complete, final_tumor_df,on=["Mouse ID", "Timepoint"], how="right")
pharma_merge
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       a203    Infubinol  Female          20          23         45
# 1       a251    Infubinol  Female          21          25         45
# 2       a262      Placebo  Female          17          29         45
# 3       a275     Ceftamin  Female          20          28         45
# 4       a366     Stelasyn  Female          16          29         30
# ..       ...          ...     ...         ...         ...        ...
# 243     z435     Propriva  Female          12          26         10
# 244     z578     Ramicane    Male          11          16         45
# 245     z581    Infubinol  Female          24          25         45
# 246     z795     Naftisol  Female          13          29         45
# 247     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# 2             70.717621                 4
# 3             62.999356                 3
# 4             63.440686                 1
# ..                  ...               ...
# 243           48.710661                 0
# 244           30.638696                 0
# 245           62.754451                 3
# 246           65.741070                 3
# 247           73.867845                 4
#
# [248 rows x 8 columns]

# %%
aa= pharma_merge.loc[pharma_merge["Drug Regimen"]== 'Capomulin',['Mouse ID','Tumor Volume (mm3)']]
#print(aa)

# %%
# Put treatments into a list for for loop (and later for plot labels)
famous_four = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
empty_tumor = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for each_treatment in famous_four:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_volume_df = pharma_merge.loc[pharma_merge["Drug Regimen"]== each_treatment,['Mouse ID',"Tumor Volume (mm3)"] ]   
    bb= tumor_volume_df.loc[:,'Tumor Volume (mm3)']
    empty_tumor.append(bb)
     
    quartile_value = tumor_volume.quantile([.25,.5,.75])

    lowerq= quartile_value[0.25]
    upperq= quartile_value[0.75]
    iqr=upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outlier_occupancy = tumor_volume_df.loc[(tumor_volume_df['Tumor Volume (mm3)']<lower_bound)|(tumor_volume_df['Tumor Volume (mm3)']>upper_bound)]
    
    #print(each_treatment)
    #print(outlier_occupancy)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
plt.boxplot(empty_tumor)
#Add labels
plt.title('Final Tumor Volume Per Drug')
plt.ylabel ('Final Tumor Volume (mm3)')
plt.xticks([1,2,3,4], ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin'])
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
    #Identify a mouse with the Capomulin Regiment
capo_m = clean_pharma.loc[clean_pharma["Drug Regimen"]=="Capomulin"]
#capo_m
capo_mouse = clean_pharma.loc[clean_pharma['Mouse ID']=='s185']
plt.plot(capo_mouse['Timepoint'], capo_mouse['Tumor Volume (mm3)'], marker = '^')

#Clean Up Chart
plt.xlabel("Time")
plt.ylabel("Tumor Volume (mm3)")
plt.title ("Capomulin Treatment For Specimen s185")
plt.grid (alpha =.2)
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
avg_tumor = capo_m.groupby(['Mouse ID']).mean()
plt.scatter(avg_tumor['Weight (g)'],avg_tumor['Tumor Volume (mm3)'], s=100, color = "blue")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
